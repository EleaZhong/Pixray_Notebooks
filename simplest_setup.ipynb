# %% [markdown]
# <a href="https://colab.research.google.com/github/DazhiZhong/Pixray_Notebooks/blob/main/simplest_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#don't need to restart runtime :)
# !pip install https://dazhi.art/f/pixray-1.5.1-py3-none-any.whl &> /dev/null

# %%
import pixray

pixray.run(
    "heavy gouache oil painting",
    "vdiff",
    size=[512,512], 
    init_image="https://dazhi.art/i/pepper.jpeg",
    init_image_alpha=255,
    vdiff_init_skip=0.8, 
    iterations=200,
    learning_rate=0.01
    #any pixray settings...
)
# Out:
# Using seed: 8552670919545817048
# All CLIP models already loaded:  ['ViT-B/32', 'ViT-B/16']
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['heavy gouache oil painting']
# Using initial image https://dazhi.art/i/pepper.jpeg (1)
# ...
# writing to:  output.png
# iter: 0, loss: 2, losses: 0.937, 0.0588, 0.945, 0.0569 (-0=>1.998)
# writing to:  output.png
# iter: 10, loss: 1.82, losses: 0.854, 0.0583, 0.855, 0.0568 (-0=>1.824)
# writing to:  output.png
# iter: 20, loss: 1.8, losses: 0.846, 0.0584, 0.842, 0.0563 (-0=>1.803)
# writing to:  output.png
# iter: 30, loss: 1.79, losses: 0.839, 0.0587, 0.837, 0.0567 (-1=>1.784)
# writing to:  output.png
# iter: 40, loss: 1.78, losses: 0.835, 0.0591, 0.83, 0.0567 (-0=>1.78)
# writing to:  output.png
# iter: 50, loss: 1.78, losses: 0.83, 0.0588, 0.832, 0.0555 (-6=>1.773)
# writing to:  output.png
# iter: 60, loss: 1.79, losses: 0.842, 0.0564, 0.84, 0.0551 (-16=>1.773)
# writing to:  output.png
# ...
